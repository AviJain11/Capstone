# %% [markdown]
# ## Introduction/Business Problem

# %% [markdown]
# Abbys FoodTruck Company is looking to understand which are the trending areas in New York. The company has 4 Food Trucks and wants to identify 4 area clusters where they can place their food trucks. They want to understand can clear boundaries be definied in clusters based on vanue categories.

# %% [markdown]
# #### Client – Abbys FoodTruck Company
# #### Target audience - Abbys management and marketing team
# #### Area of business – Food, Restaurants
# #### Location – New York
# #### Time of operation – morning (7 am – 4 pm)

# %% [markdown]
# ## Data Source
#
# Foursquare API Places Data - New York Using Developers Account
#
# It includes data like name of place/venue, venue category like Restaurant, bakery, spa, etc, address, location cordinates, tips/ratings among few others
#
# Link to Foursquare Developers for reference https://developer.foursquare.com/
#
# We will not be using any other source of data

# %% [markdown]
# ## Methodology
#
# We start with exploring the venues around Conrad hotel. We take 100 nearby places
#
# 1) We then get the list of 100 nearby places in the vicinity from Foursquare.
#
# 2) Next we apply clusterin method to find 4 clusters to see if clear boandaries between areas/clusters can be defined based on venue categories and address

# %% [markdown]
# ## Results
# We identify that while we get 4 clusters, clear boundaries cannot be established just based on venue categories. The results are clear and if the client want to explore further we need to add more features like tips/ratings.

# %%
from IPython.display import Image
PATH = "C:/Users/jainav01/Documents/Learning/IBM Data Science/Applied Data Science Capstone/Week 4 & 5/"
Image(filename = PATH + "Result.PNG", width=100, height=100)

# %% [markdown]
# ## Discussion
# All the results alongwith code & documentation is available on the sub5f.ipynb Notebook.

# %% [markdown]
# ## Conclusion
# Very interesting findings based on the set of analysis. The client can further decide to expand scope and we can explore further using more features. We can also leverage other sources of data like wikipedia and obtain more features post discussion with client and clarifying the scope of further analysis. The data science process is iterative in nature and the client should be taken on the journey along with us, best results cannot come by working in isolation without discussing with the client.
